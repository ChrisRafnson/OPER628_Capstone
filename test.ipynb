# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
data = np.load("test_cases/graph_test_cases/undirected/size_10_density_0.5.npy")
plt.imshow(data[1], cmap='viridis', interpolation='nearest')
plt.colorbar(label="Edge Weight")  # Add a color bar for the weights
plt.title("Adjacency Matrix Heatmap")
plt.xlabel("Node")
plt.ylabel("Node")
plt.show()
