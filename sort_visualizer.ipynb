# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df_random = pd.read_csv("sort_data/selection_sort_generate_random_list.csv")
# df_random1 = pd.read_csv("sort_data/quick_sort_generate_random_list.csv")

# df_almost = pd.read_csv("sort_data/quick_sort_generate_almost_sorted_list.csv")
# df_reverse = pd.read_csv("sort_data/merge_sort_generate_almost_reverse_sorted_list.csv")

# %%
group1 = df_random.groupby('List Size')['Time Taken (s)'].mean()
# group2 = df_random1.groupby('List Size')['Time Taken (s)'].mean()
# group3 = df_reverse.groupby('List Size')['Time Taken (s)'].mean()

# groups = [group1, group2, group3]

# df_grouped = pd.concat(groups).groupby('List Size').mean()
# df_grouped.reset_index()

# %%
df = group1
df = df.reset_index()
theoretical_df = pd.DataFrame()
theoretical_df['List Size'] = [i for i in range(0, df["List Size"].iloc[-1] + 5, 5)]

# %%
# Compute theoretical times and add as a new column
linearithmic_normalizer = df['Time Taken (s)'].iloc[1] / (df["List Size"].iloc[1] * np.log2(df["List Size"].iloc[1]))
theoretical_df["Linearithmic Time (s)"] = linearithmic_normalizer * theoretical_df['List Size'] * np.log2(theoretical_df['List Size'])

# Compute theoretical times and add as a new column
linear_normalizer = df["Time Taken (s)"].iloc[1] / (df["List Size"].iloc[1])
theoretical_df["Linear Time (s)"] = linear_normalizer * theoretical_df['List Size']

# Compute theoretical times and add as a new column
poloynomial_normalizer = df["Time Taken (s)"].iloc[1] / (df["List Size"].iloc[1] ** 2)
theoretical_df["Polynomial Time (s)"] = poloynomial_normalizer * (theoretical_df["List Size"] ** 2)
# Out:
# c:\Users\brat2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
theoretical_df
# Out:
#       List Size  Linearithmic Time (s)  Linear Time (s)  Polynomial Time (s)
# 0             0                    NaN         0.000000         0.000000e+00
# 1             5               0.000002         0.000006         5.555600e-07
# 2            10               0.000007         0.000011         2.222240e-06
# 3            15               0.000012         0.000017         5.000040e-06
# 4            20               0.000017         0.000022         8.888960e-06
# ...         ...                    ...              ...                  ...
# 1996       9980               0.026102         0.011089         2.213360e+00
# 1997       9985               0.026116         0.011095         2.215578e+00
# 1998       9990               0.026131         0.011100         2.217798e+00
# 1999       9995               0.026145         0.011106         2.220018e+00
# 2000      10000               0.026160         0.011111         2.222240e+00
#
# [2001 rows x 4 columns]

# %%
# Plot using pandas
plt.figure(figsize=(10, 6))
plt.plot(df["List Size"], df["Time Taken (s)"], 'o-', label="Measured Times")
plt.plot(theoretical_df["List Size"], theoretical_df["Linearithmic Time (s)"], '-', label=r"Theoretical $O(n \log n)$")
plt.plot(theoretical_df["List Size"], theoretical_df["Linear Time (s)"], '-', label=r"Theoretical $O(n)$")
plt.plot(theoretical_df["List Size"], theoretical_df["Polynomial Time (s)"], '-', label=r"Theoretical $O(n^2)$")



plt.xlabel("List Size")
plt.ylabel("Time (seconds)")
plt.title("Performance Comparison: Measured vs Theoretical")
plt.ylim(0,50)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Runtime Graphing

# %%
plt.plot(group1, label="Random Inputs", linestyle = '-')
plt.plot(group2, label="Almost Sorted", linestyle = '--')
plt.plot(group3, label="Almost Reverse Sorted", linestyle = ':')

plt.title('Selection Sort Performance')
plt.xlabel('Input Size (Elements in Array)')
plt.ylabel('Time to Finish Sort (Seconds)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.plot(group1, label="Random Inputs", linestyle = '-')
# ----> 2 plt.plot(group2, label="Almost Sorted", linestyle = '--')
#       3 plt.plot(group3, label="Almost Reverse Sorted", linestyle = ':')
#       5 plt.title('Selection Sort Performance')
#
# NameError: name 'group2' is not defined

# %%
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(8, 12))
ax[0].plot(group1, label='Random Input', color='red')
ax[1].plot(group2, label='Almost Sorted', color='blue')
ax[2].plot(group3, label='Almost Reverse Sorted', color='green')

for a in ax:
    a.legend()
    a.grid(True)

ax[1].set_ylabel('Time to Finish Sort (Seconds)')
plt.suptitle('Selection Sort Performance')
plt.xlabel('Input Size (Elements in Array)')
plt.tight_layout()
plt.show()

# %%
df = group1
df=df.reset_index()
theoretical_df = pd.DataFrame()

theoretical_df['List Size'] = [i for i in range(0, len(df), 5)]

# Compute theoretical times and add as a new column
linearithmic_normalizer = df.iloc[1] / (df["List Size"].iloc[1] * np.log2(df["List Size"].iloc[1]))
theoretical_df["Linearithmic Time (s)"] = linearithmic_normalizer * theoretical_df['List Size'] * np.log2(theoretical_df['List Size'])

# Compute theoretical times and add as a new column
linear_normalizer = df["Time Taken (s)"].iloc[1] / (df["List Size"].iloc[1])
theoretical_df["Linear Time (s)"] = linear_normalizer * theoretical_df['List Size']

# Compute theoretical times and add as a new column
poloynomial_normalizer = df["Time Taken (s)"].iloc[1] / (df["List Size"].iloc[1] ** 2)
theoretical_df["Polynomial Time (s)"] = poloynomial_normalizer * (theoretical_df["List Size"].iloc[1] ** 2)

# Plot using pandas
plt.figure(figsize=(10, 6))
plt.plot(df["Time Taken (s)"], 'o', label="Measured Times")
plt.plot(theoretical_df["Linearithmic Time (s)"], '-', label=r"Theoretical $O(n \log n)$")
plt.plot(theoretical_df["Linear Time (s)"], '-', label=r"Theoretical $O(n)$")
plt.plot(theoretical_df["Polynomial Time (s)"], '-', label=r"Theoretical $O(n^2)$")

plt.xlabel("List Size")
plt.ylabel("Time (seconds)")
plt.title("Performance Comparison: Measured vs Theoretical")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\brat2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Create a new DataFrame from the group object

df = group1.reset_index()
df.rename(columns={"Measured Time (s)": "Average Measured Time (s)"}, inplace=True)
df
# Out:
#     List Size  Time Taken (s)
# 0          10        0.000005
# 1          50        0.000056
# 2         100        0.000206
# 3         500        0.042094
# 4        1000        0.208888
# 5        2000        0.865950
# 6        3000        1.968934
# 7        4000        3.512495
# 8        5000        5.472962
# 9        6000        7.915201
# 10       7000       10.952508
# 11       8000       14.132743
# 12       9000       18.011633
# 13      10000       22.156763

# %%
theoretical_df = pd.DataFrame()

theoretical_df['List Size'] = [i for i in range(0, df["List Size"].iloc[-1] + 5, 5)]

# Compute theoretical times and add as a new column
c = df["Time Taken (s)"].iloc[1] / (df["List Size"].iloc[1] * np.log2(df["List Size"].iloc[1]))
theoretical_df["Theoretical Time (s)"] = c * theoretical_df['List Size'] * np.log2(theoretical_df['List Size'])

# Compute a simple linear line
linear_c = df["Time Taken (s)"].iloc[1] / df["List Size"].iloc[1]
df["Linear Time (s)"] = linear_c * df["List Size"]

# Compute a simple polynomial line
polynomial_c = df["Time Taken (s)"].iloc[1] / (df["List Size"].iloc[1] * df["List Size"].iloc[1])
df["Polynomial Time (s)"] = polynomial_c * (df["List Size"] * df["List Size"])

# Plot using pandas
plt.figure(figsize=(10, 6))
plt.plot(df["List Size"], df["Time Taken (s)"], 'o-', label="Measured Times")
plt.plot(df["List Size"], df["Theoretical Time (s)"], 's-', label=r"Theoretical $O(n \log n)$")
plt.plot(df["List Size"], df["Linear Time (s)"], 's-', label=r"Theoretical $O(n)$")
# plt.plot(df["List Size"], df["Polynomial Time (s)"], 's-', label=r"Theoretical $O(n^2)$")

plt.xlabel("List Size")
plt.ylabel("Time (seconds)")
plt.title("Performance Comparison: Measured vs Theoretical")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\brat2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\brat2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# # Memory Graphing

# %%
group1_mem = df_random.groupby('List Size')['Peak Memory Usage (bytes)'].mean()
group2_mem = df_almost.groupby('List Size')['Peak Memory Usage (bytes)'].mean()
group3_mem = df_reverse.groupby('List Size')['Peak Memory Usage (bytes)'].mean()

# %%
plt.scatter(group3_mem.index, group2_mem)
plt.show()

# %%
plt.plot(group1_mem, label="Random Inputs", linestyle = '-')
plt.plot(group2_mem, label="Almost Sorted", linestyle = '--')
plt.plot(group3_mem, label="Almost Reverse Sorted", linestyle = ':')

plt.title('Selection Sort Performance')
plt.xlabel('Input Size (Elements in Array)')
plt.ylabel('Peak Memory Usage (bytes)')
plt.legend()
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(3, 1, sharex=True, figsize=(8, 12))
ax[0].plot(group1_mem, label='Random Input', color='red')
ax[1].plot(group2_mem, label='Almost Sorted', color='blue')
ax[2].plot(group3_mem, label='Almost Reverse Sorted', color='green')

for a in ax:
    a.legend()
    a.grid(True)


ax[1].set_ylabel('Peak Memory Usage (bytes)')
plt.suptitle('Selection Sort Performance')
plt.xlabel('Input Size (Elements in Array)')
plt.tight_layout()
plt.show()
